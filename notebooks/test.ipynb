# %%
from census_istat.config import main_path
main_path
# Out:
# PosixPath('/home/max/Desktop/census_istat')

# %%
csv_path = main_path.joinpath('tmp/csv')
csv_data = csv_path.joinpath('R03_indicatori_2011_sezioni.csv')
csv_data
# Out:
# PosixPath('/home/max/Desktop/census_istat/tmp/csv/R03_indicatori_2011_sezioni.csv')

# %%
from census_istat.manage_data import read_csv

# %%
# %%time

csv_df = read_csv(csv_path=csv_data)
csv_df
# Out:
# 2023-02-19 12:37:37,594 | 32313 - Get encoding
# 2023-02-19 12:37:37,640 | 32313 - Read data
# CPU times: user 57.8 ms, sys: 1.58 ms, total: 59.3 ms
# Wall time: 58.7 ms
# Dask DataFrame Structure:
#               CODREG REGIONE CODPRO PROVINCIA CODCOM  COMUNE PROCOM SEZ2011   NSEZ    ACE CODLOC   CODASC     P1     P2     P3     P4     P5     P6     P7     P8     P9    P10    P11    P12    P13    P14    P15    P16    P17    P18    P19    P20    P21    P22    P23    P24    P25    P26    P27    P28    P29    P30    P31    P32    P33    P34    P35    P36    P37    P38    P39    P40    P41    P42    P43    P44    P45    P46    P47    P48    P49    P50    P51    P52    P53    P54    P55    P56    P57    P58    P59    P60    P61    P62    P64    P65    P66   P128   P129   P130   P131   P132   P135   P136   P137   P138   P139   P140    ST1    ST2    ST3    ST4    ST5    ST6    ST7    ST8    ST9   ST10   ST11   ST12   ST13   ST14   ST15     A2     A3     A5     A6     A7    A44    A46    A47    A48    PF1    PF2    PF3    PF4    PF5    PF6    PF7    PF8    PF9     E1     E2     E3     E4     E5     E6     E7     E8     E9    E10    E11    E12    E13    E14    E15    E16    E17    E18    E19    E20    E21    E22    E23    E24    E25    E26    E27    E28    E29    E30    E31
# npartitions=1
#                int64  object  int64    object  int64  object  int64   int64  int64  int64  int64  float64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64  int64
#                  ...     ...    ...       ...    ...     ...    ...     ...    ...    ...    ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# Dask Name: read-csv, 1 graph layer

# %%
csv_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 csv_df.head()
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/dataframe/core.py:1272, in _Frame.head(self, n, npartitions, compute)
#    1270 # No need to warn if we're already looking at all partitions
#    1271 safe = npartitions != self.npartitions
# -> 1272 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/dataframe/core.py:1306, in _Frame._head(self, n, npartitions, compute, safe)
#    1301 result = new_dd_object(
#    1302     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1303 )
#    1305 if compute:
# -> 1306     result = result.compute()
#    1307 return result
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/optimization.py:990, in SubgraphCallable.__call__(self, *args)
#     988 if not len(args) == len(self.inkeys):
#     989     raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 990 return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/core.py:149, in get(dsk, out, cache)
#     147 for key in toposort(dsk):
#     148     task = dsk[key]
# --> 149     result = _execute_task(task, cache)
#     150     cache[key] = result
#     151 result = _execute_task(out, cache)
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/dataframe/io/csv.py:141, in CSVFunctionWrapper.__call__(self, part)
#     138         rest_kwargs["usecols"] = columns
#     140 # Call `pandas_read_text`
# --> 141 df = pandas_read_text(
#     142     self.reader,
#     143     block,
#     144     self.header,
#     145     rest_kwargs,
#     146     self.dtypes,
#     147     columns,
#     148     write_header,
#     149     self.enforce,
#     150     path_info,
#     151 )
#     152 if project_after_read:
#     153     return df[self.columns]
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/dataframe/io/csv.py:196, in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#     194 df = reader(bio, **kwargs)
#     195 if dtypes:
# --> 196     coerce_dtypes(df, dtypes)
#     198 if enforce and columns and (list(df.columns) != list(columns)):
#     199     raise ValueError("Columns do not match", df.columns, columns)
#
# File ~/.cache/pypoetry/virtualenvs/census-istat-teFCa762-py3.8/lib/python3.8/site-packages/dask/dataframe/io/csv.py:297, in coerce_dtypes(df, dtypes)
#     293 rule = "\n\n%s\n\n" % ("-" * 61)
#     294 msg = "Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.\n\n%s" % (
#     295     rule.join(filter(None, [dtype_msg, date_msg]))
#     296 )
# --> 297 raise ValueError(msg)
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +--------+---------+----------+
# | Column | Found   | Expected |
# +--------+---------+----------+
# | E5     | float64 | int64    |
# | E6     | float64 | int64    |
# | E7     | float64 | int64    |
# +--------+---------+----------+
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'E5': 'float64',
#        'E6': 'float64',
#        'E7': 'float64'}
#
# to the call to `read_csv`/`read_table`.
#
# Alternatively, provide `assume_missing=True` to interpret
# all unspecified integer columns as floats.

# %%
import pandas as pd

from census_istat.config import MAIN_PATH, OUTPUT_FOLDER
MAIN_PATH, OUTPUT_FOLDER
# Out:
# (PosixPath('/home/max/Desktop/census_istat'),
#  PosixPath('/home/max/Desktop/census_istat/output'))

# %%
data_folder = OUTPUT_FOLDER.joinpath('preprocessing')
data_folder
# Out:
# PosixPath('/home/max/Desktop/census_istat/output/preprocessing')

# %%
file_list = list(data_folder.rglob("*"))
file_list
# Out:
# [PosixPath('/home/max/Desktop/census_istat/output/preprocessing/check_metadata_2001.csv'),
#  PosixPath('/home/max/Desktop/census_istat/output/preprocessing/check_metadata_1991.csv')]

# %%
import pandas as pd

data_list = []
for file in file_list:
    df = pd.read_csv(file)
    data_list.append(df)

df_final = pd.concat(data_list)
df_final.to_csv(data_folder.joinpath('compare_1991_2001.csv'))
df_final
# Out:
#                   id                          cod_pro  \
# 0   R01_DatiCPA_2001                 Codice Provincia
# 1   R02_DatiCPA_2001  Codice numerico della Provincia
# 2   R03_DatiCPA_2001  Codice numerico della Provincia
# 3   R04_DatiCPA_2001  Codice numerico della Provincia
# 4   R05_DatiCPA_2001  Codice numerico della Provincia
# 5   R06_DatiCPA_2001  Codice numerico della Provincia
# 6   R07_DatiCPA_2001  Codice numerico della Provincia
# 7   R08_DatiCPA_2001  Codice numerico della Provincia
# 8   R09_DatiCPA_2001  Codice numerico della Provincia
# 9   R10_DatiCPA_2001  Codice numerico della Provincia
# 10  R11_DatiCPA_2001  Codice numerico della Provincia
# 11  R12_DatiCPA_2001  Codice numerico della Provincia
# 12  R13_DatiCPA_2001  Codice numerico della Provincia
# 13  R14_DatiCPA_2001  Codice numerico della Provincia
# 14  R15_DatiCPA_2001  Codice numerico della Provincia
# 15  R16_DatiCPA_2001  Codice numerico della Provincia
# 16  R17_DatiCPA_2001  Codice numerico della Provincia
# 17  R18_DatiCPA_2001  Codice numerico della Provincia
# 18  R19_DatiCPA_2001  Codice numerico della Provincia
# 19  R20_DatiCPA_2001  Codice numerico della Provincia
# 0   R01_DatiCPA_1991                 Codice Provincia
# 1   R02_DatiCPA_1991                 Codice Provincia
# 2   R03_DatiCPA_1991                 Codice Provincia
# 3   R04_DatiCPA_1991                 Codice Provincia
# 4   R05_DatiCPA_1991                 Codice Provincia
# 5   R06_DatiCPA_1991                 Codice Provincia
# 6   R07_DatiCPA_1991                 Codice Provincia
# 7   R08_DatiCPA_1991                 Codice Provincia
# 8   R09_DatiCPA_1991                 Codice Provincia
# 9   R10_DatiCPA_1991                 Codice Provincia
# 10  R11_DatiCPA_1991                 Codice Provincia
# 11  R12_DatiCPA_1991                 Codice Provincia
# 12  R13_DatiCPA_1991                 Codice Provincia
# 13  R14_DatiCPA_1991                 Codice Provincia
# 14  R15_DatiCPA_1991                 Codice Provincia
# 15  R16_DatiCPA_1991                 Codice Provincia
# 16  R17_DatiCPA_1991                 Codice Provincia
# 17  R18_DatiCPA_1991                 Codice Provincia
# 18  R19_DatiCPA_1991                 Codice Provincia
# 19  R20_DatiCPA_1991                 Codice Provincia
#
#                        cod_com  \
# 0                Codice Comune
# 1   Codice numerico del Comune
# 2   Codice numerico del Comune
# 3   Codice numerico del Comune
# 4   Codice numerico del Comune
# 5   Codice numerico del Comune
# 6   Codice numerico del Comune
# 7   Codice numerico del Comune
# 8   Codice numerico del Comune
# 9   Codice numerico del Comune
# 10  Codice numerico del Comune
# 11  Codice numerico del Comune
# 12  Codice numerico del Comune
# 13  Codice numerico del Comune
# 14  Codice numerico del Comune
# 15  Codice numerico del Comune
# 16  Codice numerico del Comune
# 17  Codice numerico del Comune
# 18  Codice numerico del Comune
# 19  Codice numerico del Comune
# 0                Codice Comune
# 1                Codice Comune
# 2                Codice Comune
# 3                Codice Comune
# 4                Codice Comune
# 5                Codice Comune
# 6                Codice Comune
# 7                Codice Comune
# 8                Codice Comune
# 9                Codice Comune
# 10               Codice Comune
# 11               Codice Comune
# 12               Codice Comune
# 13               Codice Comune
# 14               Codice Comune
# 15               Codice Comune
# 16               Codice Comune
# 17               Codice Comune
# 18               Codice Comune
# 19               Codice Comune
#
#                                               pro_com  \
# 0   Codice che identifica univocamente il 'comune'...
# 1   Codice numerico che identifica univocamente il...
# 2   Codice numerico che identifica univocamente il...
# 3   Codice numerico che identifica univocamente il...
# 4   Codice numerico che identifica univocamente il...
# 5   Codice numerico che identifica univocamente il...
# 6   Codice numerico che identifica univocamente il...
# 7   Codice numerico che identifica univocamente il...
# 8   Codice numerico che identifica univocamente il...
# 9   Codice numerico che identifica univocamente il...
# 10  Codice numerico che identifica univocamente il...
# 11  Codice numerico che identifica univocamente il...
# 12  Codice numerico che identifica univocamente il...
# 13  Codice numerico che identifica univocamente il...
# 14  Codice numerico che identifica univocamente il...
# 15  Codice numerico che identifica univocamente il...
# 16  Codice numerico che identifica univocamente il...
# 17  Codice numerico che identifica univocamente il...
# 18  Codice numerico che identifica univocamente il...
# 19  Codice numerico che identifica univocamente il...
# 0   Codice che identifica univocamente il 'comune'...
# 1   Codice che identifica univocamente il 'comune'...
# 2   Codice che identifica univocamente il 'comune'...
# 3   Codice che identifica univocamente il 'comune'...
# 4   Codice che identifica univocamente il 'comune'...
# 5   Codice che identifica univocamente il 'comune'...
# 6   Codice che identifica univocamente il 'comune'...
# 7   Codice che identifica univocamente il 'comune'...
# 8   Codice che identifica univocamente il 'comune'...
# 9   Codice che identifica univocamente il 'comune'...
# 10  Codice che identifica univocamente il 'comune'...
# 11  Codice che identifica univocamente il 'comune'...
# 12  Codice che identifica univocamente il 'comune'...
# 13  Codice che identifica univocamente il 'comune'...
# 14  Codice che identifica univocamente il 'comune'...
# 15  Codice che identifica univocamente il 'comune'...
# 16  Codice che identifica univocamente il 'comune'...
# 17  Codice che identifica univocamente il 'comune'...
# 18  Codice che identifica univocamente il 'comune'...
# 19  Codice che identifica univocamente il 'comune'...
#
#                                               sez2001  \
# 0   Codice che identifica univocamente la sezione ...
# 1   Codice che identifica univocamente la sezione ...
# 2   Codice che identifica univocamente la sezione ...
# 3   Codice che identifica univocamente la sezione ...
# 4                                                 NaN
# 5   Codice che identifica univocamente la sezione ...
# 6   Codice che identifica univocamente la sezione ...
# 7   Codice che identifica univocamente la sezione ...
# 8   Codice che identifica univocamente la sezione ...
# 9   Codice che identifica univocamente la sezione ...
# 10  Codice che identifica univocamente la sezione ...
# 11  Codice che identifica univocamente la sezione ...
# 12  Codice che identifica univocamente la sezione ...
# 13  Codice che identifica univocamente la sezione ...
# 14  Codice che identifica univocamente la sezione ...
# 15  Codice che identifica univocamente la sezione ...
# 16  Codice che identifica univocamente la sezione ...
# 17  Codice che identifica univocamente la sezione ...
# 18  Codice che identifica univocamente la sezione ...
# 19  Codice che identifica univocamente la sezione ...
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                               sezione  \
# 0   Codice che identifica univocamente la sezione ...
# 1   Codice che identifica univocamente la sezione ...
# 2   Codice che identifica univocamente la sezione ...
# 3   Codice che identifica univocamente la sezione ...
# 4   Codice che identifica univocamente la sezione ...
# 5   Codice che identifica univocamente la sezione ...
# 6   Codice che identifica univocamente la sezione ...
# 7   Codice che identifica univocamente la sezione ...
# 8   Codice che identifica univocamente la sezione ...
# 9   Codice che identifica univocamente la sezione ...
# 10  Codice che identifica univocamente la sezione ...
# 11  Codice che identifica univocamente la sezione ...
# 12  Codice che identifica univocamente la sezione ...
# 13  Codice che identifica univocamente la sezione ...
# 14  Codice che identifica univocamente la sezione ...
# 15  Codice che identifica univocamente la sezione ...
# 16  Codice che identifica univocamente la sezione ...
# 17  Codice che identifica univocamente la sezione ...
# 18  Codice che identifica univocamente la sezione ...
# 19  Codice che identifica univocamente la sezione ...
# 0   Codice che identifica univocamente la sezione ...
# 1   Codice che identifica univocamente la sezione ...
# 2   Codice che identifica univocamente la sezione ...
# 3   Codice che identifica univocamente la sezione ...
# 4   Codice che identifica univocamente la sezione ...
# 5   Codice che identifica univocamente la sezione ...
# 6   Codice che identifica univocamente la sezione ...
# 7   Codice che identifica univocamente la sezione ...
# 8   Codice che identifica univocamente la sezione ...
# 9   Codice che identifica univocamente la sezione ...
# 10  Codice che identifica univocamente la sezione ...
# 11  Codice che identifica univocamente la sezione ...
# 12  Codice che identifica univocamente la sezione ...
# 13  Codice che identifica univocamente la sezione ...
# 14  Codice che identifica univocamente la sezione ...
# 15  Codice che identifica univocamente la sezione ...
# 16  Codice che identifica univocamente la sezione ...
# 17  Codice che identifica univocamente la sezione ...
# 18  Codice che identifica univocamente la sezione ...
# 19  Codice che identifica univocamente la sezione ...
#
#                                 p1                              p2  \
# 0   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 1   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 2   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 3   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 4   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 5   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 6   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 7   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 8   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 9   Popolazione residente - TOTALE  Popolazione residente - Maschi
# 10  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 11  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 12  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 13  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 14  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 15  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 16  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 17  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 18  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 19  Popolazione residente - TOTALE  Popolazione residente - Maschi
# 0   Popolazione residente - Totale  Popolazione residente - Maschi
# 1   Popolazione residente - Totale  Popolazione residente - Maschi
# 2   Popolazione residente - Totale  Popolazione residente - Maschi
# 3   Popolazione residente - Totale  Popolazione residente - Maschi
# 4   Popolazione residente - Totale  Popolazione residente - Maschi
# 5   Popolazione residente - Totale  Popolazione residente - Maschi
# 6   Popolazione residente - Totale  Popolazione residente - Maschi
# 7   Popolazione residente - Totale  Popolazione residente - Maschi
# 8   Popolazione residente - Totale  Popolazione residente - Maschi
# 9   Popolazione residente - Totale  Popolazione residente - Maschi
# 10  Popolazione residente - Totale  Popolazione residente - Maschi
# 11  Popolazione residente - Totale  Popolazione residente - Maschi
# 12  Popolazione residente - Totale  Popolazione residente - Maschi
# 13  Popolazione residente - Totale  Popolazione residente - Maschi
# 14  Popolazione residente - Totale  Popolazione residente - Maschi
# 15  Popolazione residente - Totale  Popolazione residente - Maschi
# 16  Popolazione residente - Totale  Popolazione residente - Maschi
# 17  Popolazione residente - Totale  Popolazione residente - Maschi
# 18  Popolazione residente - Totale  Popolazione residente - Maschi
# 19  Popolazione residente - Totale  Popolazione residente - Maschi
#
#                                  p3                                     p4  \
# 0   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 1   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 2   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 3   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 4   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 5   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 6   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 7   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 8   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 9   Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 10  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 11  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 12  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 13  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 14  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 15  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 16  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 17  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 18  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 19  Popolazione residente - Femmine  Popolazione residente - Celibi/nubili
# 0   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 1   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 2   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 3   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 4   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 5   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 6   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 7   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 8   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 9   Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 10  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 11  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 12  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 13  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 14  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 15  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 16  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 17  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 18  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
# 19  Popolazione residente - Femmine  Popolazione residente - Maschi Celibi
#
#     ...                                         pf10  \
# 0   ...                                          NaN
# 1   ...                                          NaN
# 2   ...                                          NaN
# 3   ...                                          NaN
# 4   ...                                          NaN
# 5   ...                                          NaN
# 6   ...                                          NaN
# 7   ...                                          NaN
# 8   ...                                          NaN
# 9   ...                                          NaN
# 10  ...                                          NaN
# 11  ...                                          NaN
# 12  ...                                          NaN
# 13  ...                                          NaN
# 14  ...                                          NaN
# 15  ...                                          NaN
# 16  ...                                          NaN
# 17  ...                                          NaN
# 18  ...                                          NaN
# 19  ...                                          NaN
# 0   ...  Famiglie residenti con 8 e oltre componenti
# 1   ...  Famiglie residenti con 8 e oltre componenti
# 2   ...  Famiglie residenti con 8 e oltre componenti
# 3   ...  Famiglie residenti con 8 e oltre componenti
# 4   ...  Famiglie residenti con 8 e oltre componenti
# 5   ...  Famiglie residenti con 8 e oltre componenti
# 6   ...  Famiglie residenti con 8 e oltre componenti
# 7   ...  Famiglie residenti con 8 e oltre componenti
# 8   ...  Famiglie residenti con 8 e oltre componenti
# 9   ...  Famiglie residenti con 8 e oltre componenti
# 10  ...  Famiglie residenti con 8 e oltre componenti
# 11  ...  Famiglie residenti con 8 e oltre componenti
# 12  ...  Famiglie residenti con 8 e oltre componenti
# 13  ...  Famiglie residenti con 8 e oltre componenti
# 14  ...  Famiglie residenti con 8 e oltre componenti
# 15  ...  Famiglie residenti con 8 e oltre componenti
# 16  ...  Famiglie residenti con 8 e oltre componenti
# 17  ...  Famiglie residenti con 8 e oltre componenti
# 18  ...  Famiglie residenti con 8 e oltre componenti
# 19  ...  Famiglie residenti con 8 e oltre componenti
#
#                                   st01                                 st06   \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# 5                                   NaN                                  NaN
# 6                                   NaN                                  NaN
# 7                                   NaN                                  NaN
# 8                                   NaN                                  NaN
# 9                                   NaN                                  NaN
# 10                                  NaN                                  NaN
# 11                                  NaN                                  NaN
# 12                                  NaN                                  NaN
# 13                                  NaN                                  NaN
# 14                                  NaN                                  NaN
# 15                                  NaN                                  NaN
# 16                                  NaN                                  NaN
# 17                                  NaN                                  NaN
# 18                                  NaN                                  NaN
# 19                                  NaN                                  NaN
# 0   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 1   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 2   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 3   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 4   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 5   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 6   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 7   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 8   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 9   Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 10  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 11  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 12  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 13  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 14  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 15  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 16  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 17  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 18  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
# 19  Numero totale di stranieri - Europa  Numero totale di stranieri - Africa
#
#                                    st09                               st12   \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# 5                                    NaN                                NaN
# 6                                    NaN                                NaN
# 7                                    NaN                                NaN
# 8                                    NaN                                NaN
# 9                                    NaN                                NaN
# 10                                   NaN                                NaN
# 11                                   NaN                                NaN
# 12                                   NaN                                NaN
# 13                                   NaN                                NaN
# 14                                   NaN                                NaN
# 15                                   NaN                                NaN
# 16                                   NaN                                NaN
# 17                                   NaN                                NaN
# 18                                   NaN                                NaN
# 19                                   NaN                                NaN
# 0   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 1   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 2   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 3   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 4   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 5   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 6   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 7   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 8   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 9   Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 10  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 11  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 12  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 13  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 14  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 15  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 16  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 17  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 18  Numero totale di stranieri - America  Numero totale di stranieri - Asia
# 19  Numero totale di stranieri - America  Numero totale di stranieri - Asia
#
#                                                 st13   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 0   Numero totale di stranieri - Australia Oceania...
# 1   Numero totale di stranieri - Australia Oceania...
# 2   Numero totale di stranieri - Australia Oceania...
# 3   Numero totale di stranieri - Australia Oceania...
# 4   Numero totale di stranieri - Australia Oceania...
# 5   Numero totale di stranieri - Australia Oceania...
# 6   Numero totale di stranieri - Australia Oceania...
# 7   Numero totale di stranieri - Australia Oceania...
# 8   Numero totale di stranieri - Australia Oceania...
# 9   Numero totale di stranieri - Australia Oceania...
# 10  Numero totale di stranieri - Australia Oceania...
# 11  Numero totale di stranieri - Australia Oceania...
# 12  Numero totale di stranieri - Australia Oceania...
# 13  Numero totale di stranieri - Australia Oceania...
# 14  Numero totale di stranieri - Australia Oceania...
# 15  Numero totale di stranieri - Australia Oceania...
# 16  Numero totale di stranieri - Australia Oceania...
# 17  Numero totale di stranieri - Australia Oceania...
# 18  Numero totale di stranieri - Australia Oceania...
# 19  Numero totale di stranieri - Australia Oceania...
#
#                                    st14                        st15   \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
# 5                                    NaN                         NaN
# 6                                    NaN                         NaN
# 7                                    NaN                         NaN
# 8                                    NaN                         NaN
# 9                                    NaN                         NaN
# 10                                   NaN                         NaN
# 11                                   NaN                         NaN
# 12                                   NaN                         NaN
# 13                                   NaN                         NaN
# 14                                   NaN                         NaN
# 15                                   NaN                         NaN
# 16                                   NaN                         NaN
# 17                                   NaN                         NaN
# 18                                   NaN                         NaN
# 19                                   NaN                         NaN
# 0   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 1   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 2   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 3   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 4   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 5   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 6   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 7   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 8   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 9   Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 10  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 11  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 12  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 13  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 14  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 15  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 16  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 17  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 18  Numero totale di stranieri - Apolidi  Numero totale di stranieri
# 19  Numero totale di stranieri - Apolidi  Numero totale di stranieri
#
#                                          st16   \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 0    Stranieri residenti totali
# 1    Stranieri residenti totali
# 2    Stranieri residenti totali
# 3    Stranieri residenti totali
# 4    Stranieri residenti totali
# 5    Stranieri residenti totali
# 6    Stranieri residenti totali
# 7    Stranieri residenti totali
# 8    Stranieri residenti totali
# 9    Stranieri residenti totali
# 10   Stranieri residenti totali
# 11   Stranieri residenti totali
# 12   Stranieri residenti totali
# 13   Stranieri residenti totali
# 14   Stranieri residenti totali
# 15   Stranieri residenti totali
# 16   Stranieri residenti totali
# 17   Stranieri residenti totali
# 18   Stranieri residenti totali
# 19   Stranieri residenti totali
#
#                                               isolato
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Sezione di censimento distinta per isolato e v...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [40 rows x 245 columns]
